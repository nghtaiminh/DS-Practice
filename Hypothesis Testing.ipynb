# %%
import pandas as pd
import scipy.stats as stats 
import numpy as np


import warnings
warnings.filterwarnings("ignore") 
from IPython import display

# %% [markdown]
# ### **Study question: Is the land average temperature 8.37**

# %% [markdown]
# We have the hypothesess:
# $$H_0: \bar{n} = 8.37$$
# $$H_a: \bar{n} \neq 8.37$$
#
# Set p-value to 0.05

# %%
global_temperatures_data = pd.read_csv("GlobalTemperatures.csv")
global_temperatures_data
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                    NaN                            NaN                 NaN
# 1                    NaN                            NaN                 NaN
# 2                    NaN                            NaN                 NaN
# 3                    NaN                            NaN                 NaN
# 4                    NaN                            NaN                 NaN
# ...                  ...                            ...                 ...
# 3187              20.699                          0.110               9.005
# 3188              18.845                          0.088               7.199
# 3189              16.450                          0.059               5.232
# 3190              12.892                          0.093               2.157
# 3191              10.725                          0.154               0.287
#
#       LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 3187                          0.170                          17.589
# 3188                          0.229                          17.049
# 3189                          0.115                          16.290
# 3190                          0.106                          15.252
# 3191                          0.099                          14.774
#
#       LandAndOceanAverageTemperatureUncertainty
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 3187                                      0.057
# 3188                                      0.058
# 3189                                      0.062
# 3190                                      0.063
# 3191                                      0.062
#
# [3192 rows x 9 columns]

# %%
population_mean = global_temperatures_data['LandAverageTemperature'].mean()
global_temperatures_data = global_temperatures_data.dropna(axis=0)
global_temperatures_data
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200  1850-01-01                   0.749                              1.105
# 1201  1850-02-01                   3.071                              1.275
# 1202  1850-03-01                   4.954                              0.955
# 1203  1850-04-01                   7.217                              0.665
# 1204  1850-05-01                  10.004                              0.617
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 1200               8.242                          1.738              -3.206
# 1201               9.970                          3.007              -2.291
# 1202              10.347                          2.401              -1.905
# 1203              12.934                          1.004               1.018
# 1204              15.655                          2.406               3.811
# ...                  ...                            ...                 ...
# 3187              20.699                          0.110               9.005
# 3188              18.845                          0.088               7.199
# 3189              16.450                          0.059               5.232
# 3190              12.892                          0.093               2.157
# 3191              10.725                          0.154               0.287
#
#       LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 1200                          2.822                          12.833
# 1201                          1.623                          13.588
# 1202                          1.410                          14.043
# 1203                          1.329                          14.667
# 1204                          1.347                          15.507
# ...                             ...                             ...
# 3187                          0.170                          17.589
# 3188                          0.229                          17.049
# 3189                          0.115                          16.290
# 3190                          0.106                          15.252
# 3191                          0.099                          14.774
#
#       LandAndOceanAverageTemperatureUncertainty
# 1200                                      0.367
# 1201                                      0.414
# 1202                                      0.341
# 1203                                      0.267
# 1204                                      0.249
# ...                                         ...
# 3187                                      0.057
# 3188                                      0.058
# 3189                                      0.062
# 3190                                      0.063
# 3191                                      0.062
#
# [1992 rows x 9 columns]

# %%
# Randomly select 100 rows from the population
sample_data = global_temperatures_data.sample(n=100, random_state=1)
sample_data
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 2437  1953-02-01                   3.629                              0.187
# 2170  1930-11-01                   6.574                              0.202
# 2088  1924-01-01                   2.339                              0.290
# 2719  1976-08-01                  13.511                              0.170
# 2459  1954-12-01                   3.559                              0.147
# ...          ...                     ...                                ...
# 2341  1945-02-01                   2.646                              0.194
# 1525  1877-02-01                   2.928                              0.584
# 1521  1876-10-01                   8.946                              0.327
# 2441  1953-06-01                  13.612                              0.216
# 2098  1924-11-01                   6.400                              0.200
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 2437               9.510                          0.190              -2.182
# 2170              12.032                          0.186               0.892
# 2088               7.912                          0.298              -3.502
# 2719              19.163                          0.234               7.646
# 2459               8.915                          0.185              -1.773
# ...                  ...                            ...                 ...
# 2341               8.373                          0.192              -3.044
# 1525               9.755                          1.222              -2.357
# 1521              14.400                          0.677               2.766
# 2441              19.461                          0.204               7.749
# 2098              11.794                          0.191               0.656
#
#       LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 2437                          0.189                          14.020
# 2170                          0.213                          14.505
# 2088                          0.377                          13.303
# 2719                          0.222                          16.671
# 2459                          0.176                          13.620
# ...                             ...                             ...
# 2341                          0.250                          13.747
# 1525                          0.872                          13.732
# 1521                          1.037                          15.047
# 2441                          0.202                          16.890
# 2098                          0.193                          14.132
#
#       LandAndOceanAverageTemperatureUncertainty
# 2437                                      0.094
# 2170                                      0.128
# 2088                                      0.134
# 2719                                      0.072
# 2459                                      0.088
# ...                                         ...
# 2341                                      0.125
# 1525                                      0.232
# 1521                                      0.175
# 2441                                      0.105
# 2098                                      0.116
#
# [100 rows x 9 columns]

# %%
def t_value(X, h_0):
    se = np.sqrt(np.var(X) / len(X))
    return (np.mean(X) - h_0) / se

def p_value(t):
    # Two-sided p-value, so we multiply by 2.
    return stats.norm.sf(abs(t))*2

# %%
t = t_value(sample_data['LandAverageTemperature'], population_mean)
t
# Out:
# 0.15804377845564133

# %%
p_value(t)
# Out:
# 0.874422301969351

# %% [markdown]
# Since 0.87 > 0.005, we fail to reject the null hypothesis. We can conclude that there is strong evidence that the average land temperature is almost 8.37

# %% [markdown]
# ### **Study question: Did the Latitude affect Average Temperature**

# %% [markdown]
# We have the hypothesess: \
# $H_0: $There is no association between Latitude and Average Temperatures \
# $H_a: $ There is association between Latitude and Average Temperature
#
# Set p-value to 0.05

# %%
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("GlobalLandTemperaturesByCity.csv")
data
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# 1         Århus      Denmark   57.05N    10.33E
# 2         Århus      Denmark   57.05N    10.33E
# 3         Århus      Denmark   57.05N    10.33E
# 4         Århus      Denmark   57.05N    10.33E
# ...         ...          ...      ...       ...
# 8599207  Zwolle  Netherlands   52.24N     5.26E
# 8599208  Zwolle  Netherlands   52.24N     5.26E
# 8599209  Zwolle  Netherlands   52.24N     5.26E
# 8599210  Zwolle  Netherlands   52.24N     5.26E
# 8599211  Zwolle  Netherlands   52.24N     5.26E
#
# [8599212 rows x 7 columns]

# %%
data = data.dropna(axis=0)
data
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 5        1744-04-01               5.788                          3.624
# 6        1744-05-01              10.644                          1.283
# 7        1744-06-01              14.051                          1.347
# 8        1744-07-01              16.082                          1.396
# ...             ...                 ...                            ...
# 8599206  2013-04-01               7.710                          0.182
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# 5         Århus      Denmark   57.05N    10.33E
# 6         Århus      Denmark   57.05N    10.33E
# 7         Århus      Denmark   57.05N    10.33E
# 8         Århus      Denmark   57.05N    10.33E
# ...         ...          ...      ...       ...
# 8599206  Zwolle  Netherlands   52.24N     5.26E
# 8599207  Zwolle  Netherlands   52.24N     5.26E
# 8599208  Zwolle  Netherlands   52.24N     5.26E
# 8599209  Zwolle  Netherlands   52.24N     5.26E
# 8599210  Zwolle  Netherlands   52.24N     5.26E
#
# [8235082 rows x 7 columns]

# %% [markdown]
# ### *Convert numeric variables to categorical*
# **AvarageTemperature can be classifed in 5 interval scale**

# %%
min_temperature = data['AverageTemperature'].min()
max_temperature = data['AverageTemperature'].max()
bins = np.linspace(min_temperature, max_temperature, 5)
temperature_labels = ["[-42.704-22.11525]", "[-22.11525--1.5265]", "[-1.5265-19.06225]", "[19.06225-39.651]"]
bins
# Out:
# array([-42.704  , -22.11525,  -1.5265 ,  19.06225,  39.651  ])

# %%
data['AvgTemp'] = pd.cut(data['AverageTemperature'], bins=bins, labels=temperature_labels)
data = data[:-1]

# %% [markdown]
# **For Latitude, we can classify into 4 major climate zones**
# 1. Tropical zone: 0°–23.5°(between the tropics)
# 2. Subtropics: 23.5°–40°
# 3. Temperate zone:  40°–60°
# 4. Cold zone(Polar zone): 60°–90°
# ![image info](https://content.meteoblue.com/en/meteoscool/general-climate-zones/climate_zones_lightbox.png)
# Reference: https://content.meteoblue.com/en/meteoscool/general-climate-zones

# %%
climate_labels = ['Tropical', 'Subtropics', 'Temperate', 'Polar']
bins = [0, 23.5, 40, 60, 90]
data['Climate'] = pd.cut(data['Latitude'].astype(str).str[:-1].astype(np.float), bins=bins, labels=climate_labels)

# %%
data
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 5        1744-04-01               5.788                          3.624
# 6        1744-05-01              10.644                          1.283
# 7        1744-06-01              14.051                          1.347
# 8        1744-07-01              16.082                          1.396
# ...             ...                 ...                            ...
# 8599205  2013-03-01               2.253                          0.267
# 8599206  2013-04-01               7.710                          0.182
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
#
#            City      Country Latitude Longitude             AvgTemp    Climate
# 0         Århus      Denmark   57.05N    10.33E  [-1.5265-19.06225]  Temperate
# 5         Århus      Denmark   57.05N    10.33E  [-1.5265-19.06225]  Temperate
# 6         Århus      Denmark   57.05N    10.33E  [-1.5265-19.06225]  Temperate
# 7         Århus      Denmark   57.05N    10.33E  [-1.5265-19.06225]  Temperate
# 8         Århus      Denmark   57.05N    10.33E  [-1.5265-19.06225]  Temperate
# ...         ...          ...      ...       ...                 ...        ...
# 8599205  Zwolle  Netherlands   52.24N     5.26E  [-1.5265-19.06225]  Temperate
# 8599206  Zwolle  Netherlands   52.24N     5.26E  [-1.5265-19.06225]  Temperate
# 8599207  Zwolle  Netherlands   52.24N     5.26E  [-1.5265-19.06225]  Temperate
# 8599208  Zwolle  Netherlands   52.24N     5.26E  [-1.5265-19.06225]  Temperate
# 8599209  Zwolle  Netherlands   52.24N     5.26E  [-1.5265-19.06225]  Temperate
#
# [8235081 rows x 9 columns]

# %%
sample_data = data.sample(n=100, random_state=1).reset_index()
sample_data
# Out:
#       index          dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0   2433126  1896-10-01               8.093                          1.510
# 1   6608504  1825-03-01              27.199                          2.235
# 2    406754  1756-09-01              17.585                          2.818
# 3   6357370  1999-11-01               1.167                          0.370
# 4   4873146  2006-05-01              23.401                          0.274
# ..      ...         ...                 ...                            ...
# 95   284054  1888-11-01              19.233                          0.784
# 96  3645762  1831-10-01              12.486                          2.120
# 97  1247953  1904-06-01              25.056                          0.618
# 98  3553379  1882-02-01               0.127                          0.625
# 99  8592354  1972-12-01              -1.250                          0.602
#
#              City        Country Latitude Longitude             AvgTemp  \
# 0          Fushun          China   40.99N   123.55E  [-1.5265-19.06225]
# 1       Sambalpur          India   21.70N    83.94E   [19.06225-39.651]
# 2         Armavir         Russia   45.81N    40.38E  [-1.5265-19.06225]
# 3            Riga         Latvia   57.05N    25.08E  [-1.5265-19.06225]
# 4          Mobile  United States   31.35N    88.59W   [19.06225-39.651]
# ..            ...            ...      ...       ...                 ...
# 95           Anbu          China   23.31N   116.21E   [19.06225-39.651]
# 96          Karaj           Iran   36.17N    51.71E  [-1.5265-19.06225]
# 97        Córdoba         Mexico   18.48N    96.34W   [19.06225-39.651]
# 98  Kahramanmaras         Turkey   37.78N    36.61E  [-1.5265-19.06225]
# 99         Zurich    Switzerland   47.42N     8.29E  [-1.5265-19.06225]
#
#        Climate
# 0    Temperate
# 1     Tropical
# 2    Temperate
# 3    Temperate
# 4   Subtropics
# ..         ...
# 95    Tropical
# 96  Subtropics
# 97    Tropical
# 98  Subtropics
# 99   Temperate
#
# [100 rows x 10 columns]

# %%
sample_data['Climate'].value_counts()
# Out:
# Tropical      41
# Temperate     34
# Subtropics    24
# Polar          1
# Name: Climate, dtype: int64

# %%
contingency_tab = pd.crosstab(sample_data['AvgTemp'], sample_data['Climate'], margins = True)
contingency_tab
# Out:
# Climate              Tropical  Subtropics  Temperate  Polar  All
# AvgTemp
# [-22.11525--1.5265]         0           0          3      1    4
# [-1.5265-19.06225]          2          12         29      0   43
# [19.06225-39.651]          39          12          2      0   53
# All                        41          24         34      1  100

# %%
observed = contingency_tab.iloc[:3,:4]
observed.index.name = None
observed.columns.name = None

# %%
expected = np.outer(contingency_tab['All'][0:3],
                   contingency_tab.loc['All'][0:4]) / 100
expected = pd.DataFrame(expected, columns=observed.columns, index=observed.index)

# %%
expected
# Out:
#                      Tropical  Subtropics  Temperate  Polar
# [-22.11525--1.5265]      1.64        0.96       1.36   0.04
# [-1.5265-19.06225]      17.63       10.32      14.62   0.43
# [19.06225-39.651]       21.73       12.72      18.02   0.53

# %%
chi_squared_stat = (((observed-expected)**2)/expected).sum().sum()
print(chi_squared_stat)
# Out:
# 84.86008959604348

# %%
crit = stats.chi2.ppf(q=0.95, # Find the critical value for 95% confidence*
                      df=6)   # df = (n_row-1)(n_col-1)

# %%
print("Critical value:", crit)
# Out:
# Critical value: 12.591587243743977

# %%
p_value = 1 - stats.chi2.cdf(x=chi_squared_stat, df=6)
print("P value: ", p_value)
# Out:
# P value:  3.3306690738754696e-16

# %% [markdown]
# A very small p-value is strong evidence that the null hypothesis is not true, so we reject the null hypothesis. We can conclude that there is an association between Latitude and Average Temperature
#
# In fact, latitude is one of the primary factors that affect temperature. Because of the difference in the amount of sunlight the Earth received, the lower the latitude, the warmer the region becomes and vice versa.
